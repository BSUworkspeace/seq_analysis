# %% [markdown]
# # Simultaneous Bayesian-Frequentist Sequential Testing of Nested Hypotheses
# ### BY JAMES 0. BERGER
# Zhao Hongqiang

# %% [markdown]
# ## 1.Introduction
#
# mainly question :
# The sequential testing of compound hypotheses is quite difficult.

# %% [markdown]
# ### solution:
# Wald (1947) generalised the sequential probability ratio test (SPRT) by using a weighting function (some kind of prior distribution).
#
# Subsequent references and efforts to deal with the problem can be found in Ghosh (1970) and Siegmund (1985)
#
# The main difficulties in the calculation of the probability of error and the problems associated with choosing an stopping rule.

# %% [markdown]
# ### the problem in unconditional frequentist testing
# for an $\alpha$ = 0.05 level test, one reports the same error probability rejection whether the data is just at the rejection boundary or far within the rejection region.
#
# The traditional classical way of addressing this problem is to
# report  p-value or attained significance level

# %% [markdown]
# Berger, Brown & Wolpert (1994) proposed  the frequentist error probabilities would equal the Bayesian posterior probabilities of the hypotheses.

# %% [markdown]
# ### 1.2 The (truncated) conditional sequential t-test
# 		an application of the new methodology to sequential t-testing.
#
# sample :X1,X2......~$\mathcal{N}\left(\theta, \sigma^{2}\right)$
#
# sequentially test $$
# H_{0}: \theta=\theta_{0} \text { versus } H_{1}: \theta \neq \theta_{0}
# $$
# The statistic Bn （defind by 4.2 and 4.4） forms the basis of a new (truncated) conditional sequential t-test, T*, defined as follows.

# %% [markdown]
# ### Step 1.
#
#  Choose constants O < R < 1 < A,
#
# m:Positive integers, maximum number of observations
#
# stopping time:$$N \equiv N_{m}=\left\{\text { first } n<m \text { such that } B_{n} \notin(R, A) ; \text { else, choose } n=m\right\}$$
#
# R:Rejection of H0's conditions
#
# A:Expected odds of accepting H0

# %% [markdown]
# ### Step 2.
#
# After stopping at time N
# $$
# \begin{cases}\text { if } B_{N} \leq 1, & \text { reject } H_{0} \text { and report error probability } \alpha^{*}\left(B_{N}\right)=\frac{B_{N}}{1+B_{N}} \\ \text { if } 1<B_{N}<a, & \text { make no decision, } \\ \text { if } B_{N} \geq a, & \text { accept } H_{0} \text { and report error probability } \beta^{*}\left(B_{N}\right)=\frac{1}{1+B_{N}}\end{cases}
# $$
#
#
# The constant a is computed through equation ( 4 · 5)

# %% [markdown]
# ### example
#
# Table 6.3 of Armitage (1975).
#
# Armitage used an approximate sequential t-test with a truncation at m=62. Assuming that R = 0.1 and A = 9 are chosen; these, together with m = 62, define the bounds on the stopping
#
# and is shown in Figure 1, which also shows the data, plotted as Bn versus n.
#
# Computation a=3.72；

# %% [markdown]
# ![image.png](attachment:image.png)
# The resulting decision boundary is also shown in Figure 1.

# %% [markdown]
# For the given data, the stopping bound A = 9 will be reached for n = 52 observations; in fact, B52 = 9.017. The test will then conclude by accepting Ho and reporting the conditional error probability
#
# The unconditional error probabilities for Type I and Type II were calculated as a' = 0.048 and B' = 0.109.

# %% [markdown]
# ### 1.3 Comments and motivation
# - 1.The main motivation for the new test is that
#
# the probability of error
# $\alpha^{*}\left(B_{N}\right)$ $\beta^{*}\left(B_{N}\right)$ =H0 H1（posterior probability）
#
# - 2.R, A and m, have a clear intuitive interpretation.
# - 3.New tests are usually computationally trivial
# - 4.The new test is compatible with SRP because the reported error probability never depends on the stopping rule

# %% [markdown]
# # 2.BASIC NOTATION

# %% [markdown]
# $X_{1}, X_{2}, \ldots, \text { be a sequence of observable random variables }$
#
# $X_{n}=\left(X_{1}, \ldots, X_{n}\right)$and let $\mathcal{F}_{n}=\sigma\left\{\underset{\sim}{X_{n}}\right\}$ denote the corresponding sigma-algebra.
#
# Here, n is time and Xn is the data available at time n.
# Let N be an appropriate stopping time (an adaptation of {Fn}) and let {FN} denote all events$D\in \mathcal{F}_{\infty}$The set determined before N。

# %% [markdown]
# 2.1: $H_{0}: \theta=\theta_{0}$ versus $H_{1}: \theta \in \Theta_{1}$
#
# for some $\theta_{0} \in \Theta, \theta_{0} \notin \Theta_{1} \subset \Theta$. usually $\Theta_{1}$ given by$\Theta_{1}=\left\{\theta \in \Theta: \theta \neq \theta_{0}\right\}$

# %% [markdown]
# In the default Bayesian framework （CF.Jeffreys（1961）），one specifies equal prior probabilities of 1/2 for Ho and H1 being true，and chooses a default prior density π($\theta$)/ 2 on $\Theta_{1}$，where π(.)  is a proper density on $\Theta_{1}$ People accept (reject) Ho because its posterior probability is greater (less) than 1/2，reported error probability is just the posterior probability of H1 ( H0).

# %% [markdown]
# For each fixed n, the marginal density functions of Xn under Ho and H1 in (2.1) are given, respectively, by
#
# 2.2: $m_{0, n}\left(x_{n}\right)=f_{n}\left(x_{n} \mid \theta_{0}\right)$ and $m_{1, n}\left(x_{n}\right)=\int_{\Theta_{1}} f_{n}\left(x_{n} \mid \theta\right) \pi(\theta) d \theta$
#
# 2.3: $H_{0}^{\prime}: X_{n} \sim m_{0, n}\left(x_{n}\right), \quad \forall n \geq 1, \quad$ versus $\quad H_{1}^{\prime}: X_{n} \sim m_{1, n}\left(x_{n}\right), \quad \forall n \geq 1, $
#
# which is based, for each fixed n>=1, on the corresponding likelihood ratio for Xn,
#
# 2.4 : $B_{n}=\frac{m_{0, n} \underset{\sim}{\left(x_{n}\right)}}{m_{1, n}\left(\underset{\sim}{\left(x_{n}\right)}\right.}$

# %% [markdown]
# H0 being true is
#
# 2.5: $\alpha^{*}\left(B_{n}\right) \equiv \operatorname{pr}\left(H_{0} \mid \underset{\sim}{x_{n}}\right)=B_{n} /\left(1+B_{n}\right)$
#
# H1 being true is
#
# 2.6：$\beta^{*}\left(B_{n}\right) \equiv \operatorname{pr}\left(H_{1} \mid x_{n}\right)=1 /\left(1+B_{n}\right)$

# %% [markdown]
# The classical sequentially test hypothesis (2.3) is to construct rejection and acceptance regions that report the probability of error for type I and type II given by a‘ and B’
#
# When considering compound choices, such as H1 in (2.1), the probability of a type II error is a function of $\theta$
#
# $\beta(\theta)=\operatorname{pr}\left(\right.$ Accepting $\left.H_{0} \mid \theta\right) \equiv P_{\theta}\left(\right.$ Accepting $\left.H_{0}\right)$, for $\theta \in \Theta_{1}$。Note, that $\left(\alpha^{\prime}, \beta^{\prime}\right)$ and $\beta(\theta)$will depend on the stop rule used.

# %% [markdown]
# # 3. THE MODIFIED BAYES-SEQUENTIAL TEST

# %% [markdown]
# In the test case of Section 2, let N be the appropriate stopping time for the sequential experiment (i.e., $\operatorname{pr}(N<\infty \mid \theta)=1 \quad \forall \theta \in \Theta)$.
#
# Let Pi denote (2.3) in $H_{i}^{\prime}, \quad i=0,1$, under the probability.
# That is, for any$\mathcal{D} \in \mathcal{F}_{N}$。
#
# $P_{0}(\mathcal{D})=\operatorname{pr}\left(\mathcal{D} \mid H_{0}^{\prime}\right) \equiv P_{\theta_{0}}(\mathcal{D})$, while
#
#
# $
# 3.1: P_{1}(\mathcal{D})=\operatorname{pr}\left(\mathcal{D} \mid H_{1}^{\prime}\right) \equiv \int_{\Theta_{1}} P_{\theta}(\mathcal{D}) \pi(\theta) d \theta
# $
#
# For $i=0,1$, let $F_{i}(\cdot)$ denote the distribution function of $B_{N}: F_{i}(b) \equiv P_{i}\left(B_{N} \leq b\right)$, $b \in \mathbb{R} .$ Wherever they exist, we write $F_{i}^{-1}$ for the inverse function of $F_{i}, i=0,1$, and denote
#
# 3.2：$\psi(s)=F_{0}^{-1}\left(1-F_{1}(s)\right) \quad$ and $\quad \psi^{-1}(s)=F_{1}^{-1}\left(1-F_{0}(s)\right)$

# %% [markdown]
# Condition $I$. Assume that the range of $B_{N}$ is of the form $\mathcal{B}=\left(R_{L}, R_{U}\right] \cup$ $\left[A_{L}, A_{U}\right)$, where $R_{U} \leq 1 \leq A_{L}, R_{L}$ could be zero, and $A_{U}$ could be infinity.
#
# assume that $\psi$ exists on $\left(R_{L}, R_{U}\right]$ and $\psi^{-1}$ exists on $\left[A_{L}, A_{U}\right)$. Since we are dealing with continuous densities, this condition will be satisfied by all but very strange stopping rules. Here are few examples.

# %% [markdown]
# Example 1. A standard "open-ended" stopping rule, familiar from the SPRT, is
#
# $$
# 3.3 : N=\min \left\{n \geq 1: \quad B_{n} \notin(R, A)\right\}
# $$
# where $R<1<A .$ If the $B_{n}$ can range from zero to infinity, it is easy to see that $\left(R_{L}, R_{U}\right]=(0, R]$ and $\left[A_{L}, A_{U}\right)=[A, \infty)$, and the remaining part of Condition I can be easily verified.

# %% [markdown]
# Example 2. With $N$ as in $(3 \cdot 3)$, consider the truncated at $m$ stopping time $N_{m}=$ $\min (N, m)$ (see also Section $(1 \cdot 2)$ ). Clearly, this is a proper stopping time. Since the range of $B_{m}$ must include 1, so must that of $B_{N} ;$ hence $R_{U}=1=A_{L} \cdot$
#
# For the examples in this paper, the range of $B_{n}$ is of the form $\left(0, C_{n}\right)$, where the $C_{n}$ are increasing in $n .$ Thus $R_{L}=0$ and $A_{U}=C_{m}$ and the range of $B_{N}$ is therefore $\mathcal{B}=\left(0, C_{m}\right) .$ The remaining part of Condition I can be easily verified.

# %% [markdown]
# Example 3. Variants on the stopping time $(3 \cdot 3)$
#
# $(i) \quad N_{m}^{1}=\min \left\{n \geq m: B_{n} \notin(R, A)\right\}$, of a "two-stage" study (with an initial sample of $m>1$ observations taken in a single batch and then followed by a sequential sampling),
#
# $(i i) \quad N_{m}^{2}=m \cdot \inf \left\{n \geq 1: \quad B_{n m} \notin(R, A)\right\}$, of a "group-sequential" study which samples (sequentially) $m$ units at-a-time.
#
#
# Corresponding to the constants $R_{U}$ and $A_{L}$ defined above, let
#
#
# $$
# 3.4 ：r=\min \left(R_{U}, \psi^{-1}\left(A_{L}\right)\right), \quad a=\max \left(A_{L}, \psi\left(R_{U}\right)\right)
# $$

# %% [markdown]
# These constants, r and a, define the "decision boundaries" for the modified Bayessequential test, T*, as follows:
# $\begin{cases}\text { if } B_{N} \leq r, & \text { reject } H_{0}, \text { and report the } \operatorname{CEP} \alpha^{*}\left(B_{N}\right)=B_{N} /\left(1+B_{N}\right) \\ \text { if } r<B_{N}<a, & \text { make no decision (though the experiment is stopped) } \\ \text { if } B_{N} \geq a, & \text { accept } H_{0}, \text { and report the } \operatorname{CEP} \beta^{*}\left(B_{N}\right)=1 /\left(1+B_{N}\right)\end{cases}$
#
#
#
# 3.6 $S\left(B_{N}\right)=\min \left(B_{N}, \psi^{-1}\left(B_{N}\right)\right)$

# %% [markdown]
# $$
# \begin{aligned}
# \alpha(s) &=\operatorname{pr}\left(B_{N} \leq r \mid \theta_{0}, S\left(B_{N}\right)=s\right) \\
# \beta(s \mid \theta) &=\operatorname{pr}\left(B_{N} \geq a \mid \theta, S\left(B_{N}\right)=s\right), \theta \in \Theta_{1}
# \end{aligned}
# $$
#
#
# THEOREM 1 . Consider the test $T^{*}$, of the simple versus composite hypotheses $(2 \cdot 1)$, under Condition I and with the conditioning statistic $S\left(B_{N}\right)$ given in $(3 \cdot 6)$. Then, in the rejection and acceptance regions, respectively,
# $$
# 3.8: \alpha^{*}\left(B_{N}\right)=\alpha(s) \quad \text { and } \quad \beta^{*}\left(B_{N}\right)=\int_{\Theta_{1}} \beta(s \mid \theta) \pi(\theta \mid s) d \theta
# $$
# where $\pi(\theta \mid s)$ denotes the posterior density of $\theta$ conditional on $H_{1}$ being true and on the observed value s of $S\left(B_{N}\right)$.

# %% [markdown]
# The first equality in $(3 \cdot 8)$ provides the key result
# that the conditional Type I error probability in $(3 \cdot 7)$ and the posterior probability of $H_{0}$ in $(2 \cdot 5)$ are equal.
#
# he second equality states that $\beta^{*}\left(B_{N}\right)$ in $(2 \cdot 6)$ (the posterior probability of $\left.H_{1}\right)$ is the average of the conditional Frequentist Type II error probability

# %% [markdown]
# ### 分层贝叶斯（Hierarchical bayesian）
#
# 让 $y_{j}$ 成为一个观察和 $\theta_{j}$ 控制数据生成过程的参数 $y_{j}$. 进一步假设参数 $\theta_{1}, \theta_{2}, \ldots, \theta_{j}$ 由一个共同的群体交换生成, 分布由一个超参数控制 $\phi$. 贝叶斯分层模型包含以下阶段:
#
# Stage I: $y_{j} \mid \theta_{j}, \phi \sim P\left(y_{j} \mid \theta_{j}, \phi\right)$
#
# Stage II: $\theta_{j} \mid \phi \sim P\left(\theta_{j} \mid \phi\right)$
#
# Stage III: $\phi \sim P(\phi)$

# %% [markdown]
# 在第一阶段看到的可能性是 $P\left(y_{j} \mid \theta_{j}, \phi\right)$, 和 $P\left(\theta_{j}, \phi\right)$ 作为其先验分布。请注意, 可能性取决于 $\phi$ 只有通过 $\theta_{j}$.
# 第一阶段的先验分布可以分解为:
# $P\left(\theta_{j}, \phi\right)=P\left(\theta_{j} \mid \phi\right) P(\phi)$ 【来自条件概率的定义】
# 和 $\phi$ 作为具有超先验分布的超参数, $P(\phi)$.
# 因此, 后验分布与:
# $P\left(\phi, \theta_{j} \mid y\right) \propto P\left(y_{j} \mid \theta_{j}, \phi\right) P\left(\theta_{j}, \phi\right)$ [使用贝叶斯定理]
#
# $P\left(\phi, \theta_{j} \mid y\right) \propto P\left(y_{j} \mid \theta_{j}\right) P\left(\theta_{j} \mid \phi\right) P(\phi)^{[13]}$

# %% [markdown]
# # 4. APPLICATION

# %% [markdown]
# In this section we illustrate the application of the proposed conditional sequential testing procedure to the "two-sided" normal testing problem.
#
# X1,X2...~i.i.d $\mathcal{N}\left(\theta, \sigma^{2}\right)$

# %% [markdown]
# case1
# In Table 1 below we compute a for the common default choice of $\xi=2$ and various values of R and A.
# including the unconditional probabilities of Type I and Type II errors, $\alpha^{\prime}=$
# $\operatorname{pr}\left(B_{N}<r \mid H_{0}^{\prime}\right)$ and $\beta^{\prime}=\operatorname{pr}\left(B_{N}>a \mid H_{1}^{\prime}\right)$
#
# the expected stopping times
# $\left(E_{0}(N), E_{1}(N)\right)$ and variances $\left(\operatorname{var}_{0}(N), \operatorname{var}_{1}(N)\right)$ under $H_{0}^{\prime}$ and $H_{1}^{\prime}$
#
# the corresponding probabilities of no-decision, $p_{0}=\operatorname{pr}\left(r<B_{N}<a \mid H_{0}^{\prime}\right)$,and $p_{1}=\operatorname{pr}\left(r<B_{N}<a \mid H_{1}^{\prime}\right)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  We continue with the sequential test of (4· 1), but now assume that both $\left(\theta, \sigma^{2}\right)$ are unknown.
# using a hierarchical prior structure defined as follows.
#
# For the first-stage prior distribution of $\theta$, take $\pi_{1}\left(\theta \mid \sigma^{2}, \xi\right)=\mathcal{N}\left(\theta_{0}, \xi \sigma^{2}\right)$.
#
# For the second-stage prior of $\left(\sigma^{2}, \xi\right)$, take $\pi_{2}\left(\sigma^{2}, \xi\right)=\sigma^{-2} g(\xi) d \sigma^{2} d \xi$,
#
#
#
# $$
# 4.2 ：
# B_{n}=\left(n-1+y_{n}\right)^{-n / 2} \times\left[\int_{0}^{\infty} \frac{(1+n \xi)^{(n-1) / 2}}{\left[(n-1)(1+n \xi)+y_{n}\right]^{n / 2}} g(\xi) d \xi\right]^{-1}
# $$
# where $y_{n}=n\left(\bar{x}-\theta_{0}\right)^{2} / S_{n}^{2}$ and $S_{n}^{2}$ is the usual sample variance.

# %% [markdown]
# $n \geq 2$, we write the density of $y_{n}$ as $f\left(y_{n} \mid \mu\right)$, where $\mu=\left(\theta-\theta_{0}\right) / \sigma$.
# Then the test can be rewritten as a test of $H_{0}: \mu=0$, which is a simple hypothesis.
# under $H_{1}$, **the hierarchical prior defined earlier becomes:**$\pi_{1}(\mu \mid \xi)$ is $\mathcal{N}(0, \xi)$, while $\xi>0$ still has proper prior $g(\xi)$. The implied prior, $\pi(\mu)=\int \pi_{1}(\mu \mid \xi) g(\xi) d \xi$
#
# in this case, the marginal density of $y_{n}$ under $H_{0}$ and $H_{1}$, respectively, becomes $m_{0, n}\left(y_{n}\right)=m\left(y_{n} \mid 0\right)$ and $m_{1, n}\left(y_{n}\right)=\int m\left(y_{n} \mid \xi\right) g(\xi) d \xi$, where $K_{n}=\Gamma\left(\frac{n}{2}\right)(n-1)^{(n-1) / 2} / \Gamma\left(\frac{1}{2}\right) \Gamma\left(\frac{n}{2}-\frac{1}{2}\right)$ and
#
# marginal density
# $$
# 4.3 ： m\left(y_{n} \mid \xi\right)=\int f\left(y_{n} \mid \mu\right) \pi_{1}(\mu \mid \xi) d \mu=K_{n} \frac{y_{n}^{-1 / 2}(1+n \xi)^{(n-1) / 2}}{\left[(n-1)(1+n \xi)+y_{n}\right]^{n / 2}}
# $$
# prior：
# $$
# 4.4 ： g(\xi)=(2 \pi)^{-\frac{1}{2}} \xi^{-\frac{3}{2}} \exp \left\{-\frac{1}{2 \xi}\right\}, \quad \xi>0
# $$

# %% [markdown]
# For some predetermined stopping boundaries $R$ and $A(R<1<A)$, we consider, as in Section $1 \cdot 2$, the truncated at $m$ stopping time $N_{m}$, discussed in Example 2 . Along the same lines, it can be easily verified that the test $T^{*}$ in $(3 \cdot 5)$ applies here with $R_{U}=A_{L}=1$, so that, by $(3 \cdot 4), a$ satisfies the equation
# $$
# F_{0}(a)=1-F_{1}(1)
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUESTION
# 1. How to explain this table
# 2. at Hierarchical Bayesian
